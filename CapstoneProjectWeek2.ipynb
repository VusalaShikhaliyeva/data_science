# %% [markdown]
# # What is the best location for new coffeeshop, bookstore and bookcafe in Baku?
# ## Vusala Shikhaliyeva
# ### This notebook is based on Capstone Project in Coursera courses
# #### Week2

# %% [markdown]
# ## Launching new cooffee/book shop and bookcafe in Baku
#
# - Build a dataframe of neighborhoods in Baku by reading html data from website
# - Get the geographical coordinates of the neighborhoods
# - Show the venue data for the neighborhoods from Foursquare API
# - Explore and cluster the neighborhoods
# - Select the best cluster to open a new coffeeshop, bookshop or bookcafe

# %%
import pandas as pd
import numpy as np
#!pip install folium
import folium
import requests
import json
#!pip install geocoder
import geocoder
import matplotlib.cm as cm
import matplotlib.colors as colors
from sklearn.cluster import KMeans
from geopy.geocoders import Nominatim
from bs4 import BeautifulSoup
from pandas.io.json import json_normalize
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)

# %% [markdown]
# ### Get data about neighborhoods in Baku

# %%
data = requests.get("https://en.wikipedia.org/wiki/Category:Baku_geography_stubs").text
soup = BeautifulSoup(data, 'html.parser')

regionList = []

for row in soup.find_all("div", class_="mw-content-ltr")[0].findAll("li"):
    regionList.append(row.text)
del regionList[:3]

regions = pd.DataFrame({"Neighborhood": regionList})

regions.head()
# Out:
#   Neighborhood
# 0     Badamdar
# 1    Bakıxanov
# 2     Balaxanı
# 3     Baş Ələt
# 4   Bibiheybət

# %% [markdown]
# ### Getting geolocations of the regions

# %%
def get_latlng(university):
    coordinats = None
    while(coordinats is None):
        i = geocoder.arcgis('{}, Baku, Azerbaijan'.format(university))
        coordinats = i.latlng
    return coordinats

coordinats = [ get_latlng(university) for university in regions["Neighborhood"].tolist() ]
coordinats
# Out:
# [[40.361599648164855, 49.81508025040292],
#  [40.43198000000007, 49.95330000000007],
#  [40.46255072907915, 49.9343836061088],
#  [40.410660000000064, 49.87222000000003],
#  [40.33624099687983, 49.82380512464341],
#  [40.44440000000003, 49.805660000000046],
#  [40.410660000000064, 49.87222000000003],
#  [40.410660000000064, 49.87222000000003],
#  [40.466731277528304, 49.843503490449706],
#  [40.35000000000008, 49.833330000000046],
#  [40.372021668998926, 49.84465435423397],
#  [40.51789000000008, 50.11390000000006],
#  [40.49750000000006, 50.21222000000006],
#  [40.283060000000035, 49.28074000000004],
#  [40.320350000000076, 50.59199000000007],
#  [40.320350000000076, 50.59199000000007],
#  [40.316670000000045, 50.583330000000046],
#  [40.44053000000008, 50.27612000000005],
#  [40.433520000000044, 50.276380000000074],
#  [40.38513000000006, 49.94174000000004],
#  [40.410660000000064, 49.87222000000003],
#  [40.410660000000064, 49.87222000000003],
#  [40.410660000000064, 49.87222000000003],
#  [40.401200000000074, 50.334020000000066],
#  [40.458840000000066, 50.33529000000004],
#  [40.410660000000064, 49.87222000000003],
#  [40.37122000000005, 50.07868000000008],
#  [40.446390000000065, 50.22869000000003],
#  [40.40283000000005, 49.90392000000003],
#  [40.48351000000008, 50.16140000000007],
#  [40.410660000000064, 49.87222000000003],
#  [40.30430000000007, 49.62456000000003],
#  [39.98484000000008, 49.43268000000006],
#  [40.410660000000064, 49.87222000000003],
#  [40.54866000000004, 49.921910000000025],
#  [40.31741000000005, 49.72878000000003],
#  [40.46678100000001, 49.624996500000016],
#  [40.39145000000008, 49.85628000000003],
#  [40.37733000000003, 49.850130000000036],
#  [40.70458764681025, 46.3645481218088],
#  [40.456800000000044, 50.333920000000035],
#  [40.456800000000044, 50.333920000000035],
#  [40.410660000000064, 49.87222000000003],
#  [40.56388000000004, 49.890270000000044],
#  [40.29016196900005, 47.52870740700007],
#  [40.29016196900005, 47.52870740700007],
#  [40.396660000000054, 49.973070000000064],
#  [40.33621000000005, 49.79537000000005],
#  [40.394570000000044, 49.55457000000007],
#  [40.046170000000075, 49.42160000000007],
#  [40.347950000000026, 49.81066000000004],
#  [40.308250000000044, 49.59832000000006],
#  [40.424780000000055, 50.26282000000003],
#  [40.44068628524181, 49.93167454828251],
#  [40.332550000000026, 49.81531000000007],
#  [40.518680000000074, 49.96720000000005],
#  [40.518680000000074, 49.96720000000005],
#  [40.50791000000004, 50.142030000000034],
#  [40.29016196900005, 47.52870740700007],
#  [40.296440000000075, 49.45704000000006],
#  [40.16915000000006, 49.46323000000007],
#  [40.410660000000064, 49.87222000000003],
#  [40.019850000000076, 49.43238000000008],
#  [40.322280000000035, 49.603090000000066],
#  [40.36059000000006, 49.76279000000005],
#  [40.435910000000035, 49.76175000000006],
#  [40.416511359551826, 49.99333461464002],
#  [40.49115000000006, 50.18265000000008],
#  [40.36321000000004, 50.21819000000005],
#  [40.410660000000064, 49.87222000000003],
#  [40.36336000000006, 49.943070000000034],
#  [40.41219000000007, 49.77218000000005],
#  [40.38026000000008, 49.83033000000006],
#  [39.94102000000004, 49.38952000000006],
#  [40.36352063536297, 49.976614145805385],
#  [40.430990000000065, 50.03565000000003],
#  [40.479760000000056, 49.950540000000046],
#  [40.542770000000075, 50.089980000000025],
#  [40.48494000000005, 50.15656000000007],
#  [40.36710000000005, 49.98565000000008],
#  [40.363410000000044, 50.28608000000003]]

# %% [markdown]
# ### Assingning geolocations to regions

# %%
coordinats = pd.DataFrame(coordinats, columns=['Latitude', 'Longitude'])
regions['Latitude'] = coordinats['Latitude']
regions['Longitude'] = coordinats['Longitude']
regions.shape
regions.head()
# Out:
#   Neighborhood   Latitude  Longitude
# 0     Badamdar  40.361600  49.815080
# 1    Bakıxanov  40.431980  49.953300
# 2     Balaxanı  40.462551  49.934384
# 3     Baş Ələt  40.410660  49.872220
# 4   Bibiheybət  40.336241  49.823805

# %% [markdown]
# ### Creating the map of Baku

# %%
address = 'Baku, Azerbaijan'
geolocator = Nominatim(user_agent="my-application")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinates of the capital of Azerbaijan: Baku is  {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinates of the capital of Azerbaijan: Baku is  40.3754434, 49.8326748.

# %%
mapBaku = folium.Map(location=[latitude, longitude], zoom_start=11)

for lat, lng, neighborhood in zip(regions['Latitude'], regions['Longitude'], regions["Neighborhood"]):
    label = '{}'.format(neighborhood)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7).add_to(mapBaku)  
    
mapBaku
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Foursquare API usage in exploration of neighborhoods.

# %%
CLIENT_ID = "QBFJDWVSUB0GOQKFAHKNMVM0RWAKFEEFIEB13RZAXBVAFZIX" 
CLIENT_SECRET = "NIURO4Z0K1AYNJVUJYJJP5YLZ4FPF2KC4HAAUWJ0RAN0IETK" 
VERSION = '20191204' 

print('My credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# My credentails:
# CLIENT_ID: QBFJDWVSUB0GOQKFAHKNMVM0RWAKFEEFIEB13RZAXBVAFZIX
# CLIENT_SECRET:NIURO4Z0K1AYNJVUJYJJP5YLZ4FPF2KC4HAAUWJ0RAN0IETK

# %%
radius = 2000
LIMIT = 100

region = []

for lat, long, neighborhood in zip(regions['Latitude'], regions['Longitude'], regions['Neighborhood']):

    url = "https://api.foursquare.com/v2/venues/explore?client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}".format(
        CLIENT_ID,
        CLIENT_SECRET,
        VERSION,
        lat,
        long,
        radius, 
        LIMIT)
    
    results = requests.get(url).json()["response"]['groups'][0]['items']
    
    for i in results:
        region.append((
            neighborhood,
            lat, 
            long, 
            i['venue']['name'], 
            i['venue']['location']['lat'], 
            i['venue']['location']['lng'],  
            i['venue']['categories'][0]['name']))

region_df = pd.DataFrame(region)

region_df.columns = ['Neighborhood', 'Latitude', 'Longitude', 'VenueName', 'VenueLatitude', 'VenueLongitude', 'VenueCategory']

print(region_df.shape)
region_df.head()
# Out:
# (2125, 7)
#   Neighborhood  Latitude  Longitude              VenueName  VenueLatitude  \
# 0     Badamdar   40.3616   49.81508               Beerbaşa      40.363921
# 1     Badamdar   40.3616   49.81508  Nakhchivan Restaurant      40.363588
# 2     Badamdar   40.3616   49.81508         Şəki Restoranı      40.357243
# 3     Badamdar   40.3616   49.81508                Bouquet      40.363285
# 4     Badamdar   40.3616   49.81508                 Buxara      40.362943
#
#    VenueLongitude            VenueCategory
# 0       49.818902                  Brewery
# 1       49.819427               Restaurant
# 2       49.811641               Restaurant
# 3       49.820232              Flower Shop
# 4       49.816071  Comfort Food Restaurant

# %%
region_df.groupby(["Neighborhood"]).count()
# Out:
#                   Latitude  Longitude  VenueName  VenueLatitude  \
# Neighborhood
# Badamdar               100        100        100            100
# Bakıxanov               24         24         24             24
# Balaxanı                 5          5          5              5
# Baş Ələt                69         69         69             69
# Bibiheybət              57         57         57             57
# Bilgəh                  69         69         69             69
# Biləcəri                11         11         11             11
# Binə, Baku              69         69         69             69
# Binəqədi raion          11         11         11             11
# Bukhta-Ilicha          100        100        100            100
# Buzovna                 16         16         16             16
# Bülbülə                100        100        100            100
# Cənubi                   7          7          7              7
# Dzhabar                  3          3          3              3
# Dübəndi                  2          2          2              2
# Gobustan, Baku          69         69         69             69
# Gürgan                   4          4          4              4
# Gürgən-Pirallahı        11         11         11             11
# Heybət                  69         69         69             69
# Hövsan                  11         11         11             11
# Keshla                  21         21         21             21
# Khazar raion            19         19         19             19
# Khazri                  69         69         69             69
# Korgöz                   1          1          1              1
# Kotal                    3          3          3              3
# Kura Rock               69         69         69             69
# Kürdəxanı                4          4          4              4
# Kələzağ                  1          1          1              1
# Lökbatan                10         10         10             10
# Müşfiqabad               5          5          5              5
# Nizami raion            13         13         13             13
# Nərimanov raion        100        100        100            100
# Nəsimi raion           100        100        100            100
# Pirallahy raion         10         10         10             10
# Pirallahı, Baku         10         10         10             10
# Pirsaat, Baku           69         69         69             69
# Pirşağı                  4          4          4              4
# Qaradağ raion           23         23         23             23
# Qarakosa                 3          3          3              3
# Qaraçuxur               47         47         47             47
# Qaya                    44         44         44             44
# Qoşaqışlaq               2          2          2              2
# Rəsulzadə               14         14         14             14
# Sabail raion            24         24         24             24
# Sabunçu raion            6          6          6              6
# Sabunçu, Baku            6          6          6              6
# Sanqaçal                 2          2          2              2
# Shikhov Beach           69         69         69             69
# Shuvalan                22         22         22             22
# Sulutəpə                 8          8          8              8
# Suraxanı raion          15         15         15             15
# Türkan                   3          3          3              3
# Xocəsən                  4          4          4              4
# Xətai raion             37         37         37             37
# Yasamal raion          100        100        100            100
# Yeni Günəşli            18         18         18             18
# Yeni Suraxanı            2          2          2              2
# Yeni Ələt                1          1          1              1
# Zabrat                   5          5          5              5
# Zağulba Bağları          7          7          7              7
# Zirə                     2          2          2              2
# Zığ, Baku               16         16         16             16
# Zəfəran                 17         17         17             17
# Üçtəpə, Baku            69         69         69             69
# Şağan                   16         16         16             16
# Şubanı                   1          1          1              1
# Şıxlar, Baku             2          2          2              2
# Əhmədli, Baku           87         87         87             87
# Ələt                    69         69         69             69
# Əmircan, Baku           69         69         69             69
#
#                   VenueLongitude  VenueCategory
# Neighborhood
# Badamdar                     100            100
# Bakıxanov                     24             24
# Balaxanı                       5              5
# Baş Ələt                      69             69
# Bibiheybət                    57             57
# Bilgəh                        69             69
# Biləcəri                      11             11
# Binə, Baku                    69             69
# Binəqədi raion                11             11
# Bukhta-Ilicha                100            100
# Buzovna                       16             16
# Bülbülə                      100            100
# Cənubi                         7              7
# Dzhabar                        3              3
# Dübəndi                        2              2
# Gobustan, Baku                69             69
# Gürgan                         4              4
# Gürgən-Pirallahı              11             11
# Heybət                        69             69
# Hövsan                        11             11
# Keshla                        21             21
# Khazar raion                  19             19
# Khazri                        69             69
# Korgöz                         1              1
# Kotal                          3              3
# Kura Rock                     69             69
# Kürdəxanı                      4              4
# Kələzağ                        1              1
# Lökbatan                      10             10
# Müşfiqabad                     5              5
# Nizami raion                  13             13
# Nərimanov raion              100            100
# Nəsimi raion                 100            100
# Pirallahy raion               10             10
# Pirallahı, Baku               10             10
# Pirsaat, Baku                 69             69
# Pirşağı                        4              4
# Qaradağ raion                 23             23
# Qarakosa                       3              3
# Qaraçuxur                     47             47
# Qaya                          44             44
# Qoşaqışlaq                     2              2
# Rəsulzadə                     14             14
# Sabail raion                  24             24
# Sabunçu raion                  6              6
# Sabunçu, Baku                  6              6
# Sanqaçal                       2              2
# Shikhov Beach                 69             69
# Shuvalan                      22             22
# Sulutəpə                       8              8
# Suraxanı raion                15             15
# Türkan                         3              3
# Xocəsən                        4              4
# Xətai raion                   37             37
# Yasamal raion                100            100
# Yeni Günəşli                  18             18
# Yeni Suraxanı                  2              2
# Yeni Ələt                      1              1
# Zabrat                         5              5
# Zağulba Bağları                7              7
# Zirə                           2              2
# Zığ, Baku                     16             16
# Zəfəran                       17             17
# Üçtəpə, Baku                  69             69
# Şağan                         16             16
# Şubanı                         1              1
# Şıxlar, Baku                   2              2
# Əhmədli, Baku                 87             87
# Ələt                          69             69
# Əmircan, Baku                 69             69

# %%
print('There are {} uniques categories.'.format(len(region_df['VenueCategory'].unique())))
# Out:
# There are 181 uniques categories.

# %%
"Neighborhood" in venues_df['VenueCategory'].unique()
# Out:
# False

# %% [markdown]
# ### Results

# %% [markdown]
# The avability of the neighborhoods was read form Wikipedia. For today the capital of Azerbaijan has 12 neighborhoods totally. We used scrapping methods: Python packages such as requests and BeatifulSoup. We  utilized the geocode of each neighborhood in Baku, and got the exact location of them. We will use Foursquare API to order to get venue data for neighborhoods. Additionally, using this API we get crucial categorical information which help to figure out business problem of my project. In this project, Web Scrapping, working with Foursquare API, data cleaning and wrangling, machine learning and map visualization.
